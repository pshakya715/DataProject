# %% [markdown]
#  Import required libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Read csv.

# %%
characters_data = pd.read_csv("/content/drive/MyDrive/charcters_stats.csv")

# %% [markdown]
# Show first records from csv.

# %%
characters_data.head(5)
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %% [markdown]
# Show number of rows and columns.

# %%
characters_data.shape
# Out:
# (611, 9)

# %% [markdown]
# You need to find the values of alignment ,can use value_counts().

# %%
characters_data.value_counts("Alignment")
# Out:
# Alignment
# good       432
# bad        165
# neutral     11
# dtype: int64

# %% [markdown]
# Find out only good alignment holders superheroes.

# %%
characters_data1 =characters_data.groupby('Alignment')
characters_data2 = characters_data1.get_group('good')
characters_data2
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 6        Adam Monroe      good            63        10     12         100
# ..               ...       ...           ...       ...    ...         ...
# 604            X-Man      good            88        53     53          95
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
#
#      Power  Combat  Total
# 0       25      52    233
# 1       17      64    316
# 2       35      85    299
# 3       84      65    406
# 6       71      64    320
# ..     ...     ...    ...
# 604     92      84    465
# 606     12      14    164
# 607     31      28    182
# 608     83      28    388
# 609    100      56    292
#
# [432 rows x 9 columns]

# %% [markdown]
# Show first five records which you found in point 6.

# %%
characters_data2.head(5)
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 6  Adam Monroe      good            63        10     12         100     71
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 6      64    320

# %% [markdown]
# Show top five records having top speed of heroes of good alignment.

# %%
char_good_speed = characters_data2.sort_values(by='Speed', ascending=False)
char_good_speed.head(5)
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 231       Flash III      good            63        10    100          60
# 304  Jack of Hearts      good            63        55    100          30
# 295         Impulse      good            50        10    100          60
# 525        Stardust      good            88        85    100         110
# 447     Quicksilver      good            63        28    100          60
#
#      Power  Combat  Total
# 231     83      32    348
# 304     70      30    348
# 295     63      60    343
# 525    100      85    568
# 447     57      56    364

# %% [markdown]
# Show 5 records of super heroes who have maximum power of good alignment.

# %%
character_data3 = characters_data2.sort_values(by='Power', ascending=False).head(5)
character_data3
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 609        Zatanna      good            75        10     23          28
# 546           Thor      good            69       100     92         100
# 511          Spawn      good            75        60     50          90
# 69   Beta Ray Bill      good            63        80     35          95
# 70        Beyonder      good            88       100     23         100
#
#      Power  Combat  Total
# 609    100      56    292
# 546    100      85    546
# 511    100      95    470
# 69     100      84    457
# 70     100      56    467

# %% [markdown]
# Find out how many super heroes are there with power 100 of good alignment.

# %%
char_data_power = characters_data2.sort_values(by='Power', ascending=False)
char_data_power
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 609         Zatanna      good            75        10     23          28
# 546            Thor      good            69       100     92         100
# 511           Spawn      good            75        60     50          90
# 69    Beta Ray Bill      good            63        80     35          95
# 70         Beyonder      good            88       100     23         100
# ..              ...       ...           ...       ...    ...         ...
# 127       Bumbleboy      good             1         1      1           1
# 124  Brother Voodoo      good             1         1      1           1
# 415     Nite Owl II      good             1         1      1           1
# 120         Box III      good             1         1      1           1
# 100     Blaquesmith      good             1         1      1           1
#
#      Power  Combat  Total
# 609    100      56    292
# 546    100      85    546
# 511    100      95    470
# 69     100      84    457
# 70     100      56    467
# ..     ...     ...    ...
# 127      0       1      5
# 124      0       1      5
# 415      0       1      5
# 120      0       1      5
# 100      0       1      5
#
# [432 rows x 9 columns]

# %%
char_data_pwr_ct = char_data_power[char_data_power.Power == 100]
char_data_pwr_ct.count()
# Out:
# Name            33
# Alignment       33
# Intelligence    33
# Strength        33
# Speed           33
# Durability      33
# Power           33
# Combat          33
# Total           33
# dtype: int64

# %% [markdown]
#  Shape them what you got in point 10.

# %%
char_data_pwr_ct.shape
# Out:
# (33, 9)

# %% [markdown]
#  Show all records from point 10.

# %%
char_data_pwr_ct
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 609            Zatanna      good            75        10     23          28
# 546               Thor      good            69       100     92         100
# 511              Spawn      good            75        60     50          90
# 69       Beta Ray Bill      good            63        80     35          95
# 70            Beyonder      good            88       100     23         100
# 499      Silver Surfer      good            63       100     84         101
# 487        Shadow King      good            75        12     27         100
# 85          Black Bolt      good            75        67    100          84
# 435        Plastic Man      good            50        63     23         100
# 433            Phoenix      good           100        80     67         100
# 419          Offspring      good            50        10     35          99
# 418               Nova      good            38        60    100         100
# 417               Nova      good           100        85     67         101
# 129              Cable      good            88        48     23          56
# 383       Miss Martian      good            63        85     58         100
# 362        Marvel Girl      good            63        85     47          42
# 361  Martian Manhunter      good           100       100     96         100
# 185            Deadman      good            50        10     33         100
# 196        Doctor Fate      good            81        16     25          80
# 198     Doctor Strange      good           100        10     12          84
# 204       Dr Manhattan      good            88        32     42          95
# 327            Kilowog      good            81        90     53          42
# 306          Jean Grey      good           100        80     67         100
# 226          Firestorm      good            50        53     58          56
# 299           Iron Man      good           100        85     58          85
# 294             Iceman      good            63        32     53         100
# 251               Goku      good            56       100     75          90
# 525           Stardust      good            88        85    100         110
# 408     Naruto Uzumaki      good            50        80     32          80
# 266         Hal Jordan      good            63        90     53          64
# 583        War Machine      good            63        80     63         100
# 589            Watcher      good           100        80     67          89
# 547          Thor Girl      good            75        83     70          84
#
#      Power  Combat  Total
# 609    100      56    292
# 546    100      85    546
# 511    100      95    470
# 69     100      84    457
# 70     100      56    467
# 499    100      32    480
# 487    100      75    389
# 85     100      56    482
# 435    100      56    392
# 433    100      70    517
# 419    100      56    350
# 418    100      25    423
# 417    100      85    538
# 129    100      80    395
# 383    100      45    451
# 362    100      80    417
# 361    100      85    581
# 185    100      42    335
# 196    100      50    352
# 198    100      60    366
# 204    100      42    399
# 327    100      80    446
# 306    100      70    517
# 226    100      42    359
# 299    100      64    492
# 294    100      64    412
# 251    100     100    521
# 525    100      85    568
# 408    100     100    442
# 266    100      56    426
# 583    100      85    491
# 589    100      56    492
# 547    100      70    482

# %% [markdown]
#  Retrieve total of first five records of max power of good alignment super heroes

# %%
char_data_pwr = characters_data2.sort_values(by='Total', ascending=False)
char_data_pwr.head(5)
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 361  Martian Manhunter      good           100       100     96         100
# 537           Superman      good           100       100    100         100
# 525           Stardust      good            88        85    100         110
# 546               Thor      good            69       100     92         100
# 536          Supergirl      good            94        98     92         100
#
#      Power  Combat  Total
# 361    100      85    581
# 537     94      85    579
# 525    100      85    568
# 546    100      85    546
# 536     85      75    544

# %% [markdown]
# Draw a bar plot of all super heroes who are having good alignment and max power of
# top five only , take same object of point 13 , show name and total in plot with green
# bars

# %%
df = char_data_pwr.head(5)
df
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 361  Martian Manhunter      good           100       100     96         100
# 537           Superman      good           100       100    100         100
# 525           Stardust      good            88        85    100         110
# 546               Thor      good            69       100     92         100
# 536          Supergirl      good            94        98     92         100
#
#      Power  Combat  Total
# 361    100      85    581
# 537     94      85    579
# 525    100      85    568
# 546    100      85    546
# 536     85      75    544

# %%
plt.figure(figsize=(8,5))
plt.bar(list(df['Name'])[0:5],list(df['Total'])[0:5],color="g")
plt.show()

# %%
pwr_viz = df.plot(x = "Name", kind="bar", figsize=(20, 10))
pwr_viz.set_xlabel("Super Hero Name", fontsize=12)
plt.show()

# %% [markdown]
# Extract villains having bad alignment.

# %%
characters_data1

# %%
characters_data_bad = characters_data1.get_group('bad')
characters_data_bad
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 4       Abomination       bad            63        80     53          90
# 5           Abraxas       bad            88       100     83          99
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 17             Ammo       bad             1         1      1           1
# ..              ...       ...           ...       ...    ...         ...
# 586            Warp       bad            38        10     23          28
# 590       Weapon XI       bad             1         1      1           1
# 593  Willis Stryker       bad            38        16     23          28
# 605     Yellow Claw       bad             1         1      1           1
# 610            Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 4       55      95    436
# 5      100      56    526
# 11     100      40    460
# 16     100     100    575
# 17       0       1      5
# ..     ...     ...    ...
# 586     63      50    212
# 590      0       1      5
# 593     41      60    206
# 605      0       1      5
# 610     72      28    288
#
# [165 rows x 9 columns]

# %% [markdown]
# Show first five records of point 15

# %%
characters_data_bad.head(15)
# Out:
#             Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 4    Abomination       bad            63        80     53          90     55
# 5        Abraxas       bad            88       100     83          99    100
# 11    Air-Walker       bad            50        85    100          85    100
# 16         Amazo       bad            75       100    100         100    100
# 17          Ammo       bad             1         1      1           1      0
# 21        Angela       bad             1         1      1           1      0
# 23     Annihilus       bad            75        80     47          56     59
# 26  Anti-Monitor       bad            88        90     38          90    100
# 27    Anti-Spawn       bad             1         1      1           1      0
# 29    Apocalypse       bad           100       100     33         100    100
# 35      Arclight       bad            38        63     23          42     52
# 49        Azazel       bad            50        11     47          95     87
# 52          Bane       bad            88        53     23          56     51
# 67        Beetle       bad             1         1      1           1      0
# 73       Big Man       bad            75        12     23          28     19
#
#     Combat  Total
# 4       95    436
# 5       56    526
# 11      40    460
# 16     100    575
# 17       1      5
# 21       1      5
# 23      64    381
# 26      90    496
# 27       1      5
# 29      60    493
# 35      70    288
# 49      80    370
# 52      95    366
# 67       1      5
# 73      70    227

# %% [markdown]
#  Show top five fastest super villains in terms of super speed

# %%
char_bad_speed = characters_data_bad.sort_values(by='Speed', ascending=False)
char_bad_speed.head(5)
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 610            Zoom       bad            50        10    100          28
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
#
#      Power  Combat  Total
# 610     72      28    288
# 11     100      40    460
# 16     100     100    575
# 535    100      85    579
# 242     94      95    579

# %% [markdown]
# Top five super villains in terms of intelligence

# %%
characters_data_bad.sort_values(by='Intelligence', ascending=False).head(5)
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 386  Mister Mxyzptlk       bad           113        10     12          14
# 338       Lex Luthor       bad           100        10     12          14
# 336           Leader       bad           100        10     12          14
# 122         Brainiac       bad           100        28     63          90
# 194      Doctor Doom       bad           100        32     20         100
#
#      Power  Combat  Total
# 386    100      28    277
# 338     10      28    174
# 336     58      42    236
# 122     60      75    416
# 194     93      84    429

# %% [markdown]
# Show who is most dangerous super villain after calculating their total (top 5 only)

# %%
characters_data_bad.sort_values(by='Total', ascending=False).head(5)
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
# 16            Amazo       bad            75       100    100         100
# 203        Dormammu       bad            88        95     83         100
# 201        Doomsday       bad            88        80     67         120
#
#      Power  Combat  Total
# 535    100      85    579
# 242     94      95    579
# 16     100     100    575
# 203    100      80    546
# 201    100      90    545

# %% [markdown]
# Draw a histogram for speed of super heroes having fig size 10,5 , provide speed in
# histogram for only good alignment super heroes ,title should be "distribution of
# speed" , xlabel should be "speed"

# %%
char_good_speed.hist("Speed", figsize=(10,5))
plt.title('Distribution of Speed')
plt.xlabel("Speed")
plt.show()

# %% [markdown]
#  Draw a histogram for combat of super villains having fig size 10,5 , provide combat in
# histogram for only bad alignment super heroes ,title should be "distribution of
# combat" , xlabel should be "combat"

# %%
char_bad_combat = characters_data_bad.sort_values(by='Combat', ascending=False)
char_bad_combat.head(5)
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 475    Sabretooth       bad            55        53     25          90     28
# 16          Amazo       bad            75       100    100         100    100
# 449  Ra's Al Ghul       bad           100        28     32          42     27
# 464     Rick Flag       bad            88        11     23          28     19
# 180      Darkseid       bad            88       100     23         100    100
#
#      Combat  Total
# 475     100    351
# 16      100    575
# 449     100    329
# 464      95    264
# 180      95    506

# %%
char_bad_combat.hist("Combat", figsize=(10,5))
plt.title('Distribution of Combat')
plt.xlabel("Combat")
plt.show()
